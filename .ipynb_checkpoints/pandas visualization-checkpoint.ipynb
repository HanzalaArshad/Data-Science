# %%
#Reading csv
import pandas as pd
economy = pd.read_csv("D:\\Pakistan economy and GDP Sectors(1).csv" ,na_values=["NaN","Na"])
economy.head(2)

# %%
economy.tail()
# Out:
#     Year  Small Scale Manufacturing  Large Scale Manufacturing  \
# 12  2010                      0.014                      0.113
# 13  2009                      0.013                      0.115
# 14  2008                      0.012                      0.123
# 15  2007                      0.012                      0.122
# 16  2006                      0.012                      0.117
#
#     Slaughtering Manufacturing  Fishing  Livestock  Crops  Forestry  \
# 12                       0.009    0.006      0.119  0.091     0.005
# 13                       0.009    0.006      0.118  0.097     0.005
# 14                       0.009    0.006      0.116  0.093     0.005
# 15                       0.009    0.005      0.117  0.098     0.004
# 16                       0.009    0.006      0.121  0.099     0.005
#
#     Total Agriculture  Cotton Ginning  ...  Wholesale & Retail Trade  \
# 12              0.220           0.007  ...                     0.032
# ...

# %%
economy.shape
# Out:
# (17, 28)

# %%
economy.columns
# Out:
# Index(['Year', 'Small Scale Manufacturing', 'Large Scale Manufacturing',
#        'Slaughtering Manufacturing', 'Fishing', 'Livestock', 'Crops',
#        'Forestry', 'Total Agriculture', 'Cotton Ginning', 'Important Crops',
#        'Other Crops', 'Finance & Insurance', 'General Government Services',
#        'Housing Services', 'Other Private Services', 'Transport',
#        ' Storage & Communication', 'Wholesale & Retail Trade',
#        'Services Total', 'Income Per Capita', 'GDP Current Prices',
#        'GDP Constant Prices', 'Income Per Capita.1', 'Gross public Dept',
#        'Domastic Debt', 'Na', 'Gross Public Debt'],
#       dtype='object')

# %%
slice_one=economy.loc[[0,1,4],["Year","Large Scale Manufacturing"]]
slice_one
# Out:
#    Year  Large Scale Manufacturing
# 0  2022                     0.0924
# 1  2021                     0.0886
# 4  2018                     0.0934

# %%
slice_two=economy.loc[0:2,"Year":"Large Scale Manufacturing"]
slice_two
# Out:
#    Year  Small Scale Manufacturing  Large Scale Manufacturing
# 0  2022                     0.0198                     0.0924
# 1  2021                     0.0193                     0.0886
# 2  2020                     0.0187                     0.0840

# %%
economy.isnull()
economy.head(2)
# Out:
#    Year  Small Scale Manufacturing  Large Scale Manufacturing  \
# 0  2022                     0.0198                     0.0924
# 1  2021                     0.0193                     0.0886
#
#    Slaughtering Manufacturing  Fishing  Livestock   Crops  Forestry  \
# 0                      0.0121   0.0032     0.1404  0.0784    0.0049
# 1                      0.0121   0.0033     0.1441  0.0780    0.0048
#
#    Total Agriculture  Cotton Ginning  ...  Wholesale & Retail Trade  \
# 0             0.2268          0.0029  ...                    0.0619
# 1             0.2302          0.0028  ...                    0.0600
#
#    Services Total  Income Per Capita  GDP Current Prices  GDP Constant Prices  \
# 0          0.3318             1797.5            62677555             38755090
# 1          0.3611             1676.5            52213299             36572644
#
#    Income Per Capita.1  Gross public Dept  Domastic Debt  Na  \
# ...

# %%
economy.dropna(axis=0, inplace=  False).shape
# Out:
# (17, 28)

# %%
economy.fillna(0,inplace=True)
economy.tail()
# Out:
#     Year  Small Scale Manufacturing  Large Scale Manufacturing  \
# 12  2010                      0.014                      0.113
# 13  2009                      0.013                      0.115
# 14  2008                      0.012                      0.123
# 15  2007                      0.012                      0.122
# 16  2006                      0.012                      0.117
#
#     Slaughtering Manufacturing  Fishing  Livestock  Crops  Forestry  \
# 12                       0.009    0.006      0.119  0.091     0.005
# 13                       0.009    0.006      0.118  0.097     0.005
# 14                       0.009    0.006      0.116  0.093     0.005
# 15                       0.009    0.005      0.117  0.098     0.004
# 16                       0.009    0.006      0.121  0.099     0.005
#
#     Total Agriculture  Cotton Ginning  ...  Wholesale & Retail Trade  \
# 12              0.220           0.007  ...                     0.032
# ...
